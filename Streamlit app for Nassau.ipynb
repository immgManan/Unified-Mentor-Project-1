# %%
# !pip install streamlit pandas plotly
# Out:
# Collecting streamlit
#   Downloading streamlit-1.57.0-py3-none-any.whl (9.2 MB)
#      ---------------------------------------- 9.2/9.2 MB 2.5 MB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-3.0.2-cp311-cp311-win_amd64.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 4.0 MB/s eta 0:00:00
# Collecting plotly
#   Downloading plotly-6.7.0-py3-none-any.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 4.0 MB/s eta 0:00:00
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0
#   Downloading altair-6.1.0-py3-none-any.whl (796 kB)
#      -------------------------------------- 797.0/797.0 kB 6.3 MB/s eta 0:00:00
# Collecting blinker<2,>=1.5.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting cachetools<8,>=5.5
#   Downloading cachetools-7.1.1-py3-none-any.whl (16 kB)
# Collecting click<9,>=7.0
#   Downloading click-8.3.3-py3-none-any.whl (110 kB)
#      -------------------------------------- 110.5/110.5 kB 6.7 MB/s eta 0:00:00
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading gitpython-3.1.50-py3-none-any.whl (212 kB)
#      -------------------------------------- 212.5/212.5 kB 6.5 MB/s eta 0:00:00
# Collecting numpy<3,>=1.23
#   Downloading numpy-2.4.4-cp311-cp311-win_amd64.whl (12.6 MB)
#      ---------------------------------------- 12.6/12.6 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20 in c:\users\user\appdata\roaming\python\python311\site-packages (from streamlit) (26.2)
# Collecting pillow<13,>=7.1.0
#   Downloading pillow-12.2.0-cp311-cp311-win_amd64.whl (7.1 MB)
#      ---------------------------------------- 7.1/7.1 MB 3.8 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
#      ---------------------------------------- 11.3/11.3 MB 2.7 MB/s eta 0:00:00
# Collecting protobuf<8,>=3.20
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
#      -------------------------------------- 437.9/437.9 kB 9.1 MB/s eta 0:00:00
# Collecting pyarrow>=7.0
#   Downloading pyarrow-24.0.0-cp311-cp311-win_amd64.whl (27.3 MB)
#      ---------------------------------------- 27.3/27.3 MB 3.5 MB/s eta 0:00:00
# Collecting requests<3,>=2.27
#   Downloading requests-2.33.1-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.9/64.9 kB ? eta 0:00:00
# Collecting tenacity<10,>=8.1.0
#   Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Collecting toml<2,>=0.10.1
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from streamlit) (4.15.0)
# Collecting starlette>=0.40.0
#   Downloading starlette-1.0.0-py3-none-any.whl (72 kB)
#      ---------------------------------------- 72.7/72.7 kB 2.0 MB/s eta 0:00:00
# Collecting uvicorn>=0.30.0
#   Downloading uvicorn-0.46.0-py3-none-any.whl (70 kB)
#      ---------------------------------------- 70.9/70.9 kB 4.0 MB/s eta 0:00:00
# Collecting httptools>=0.6.3
#   Downloading httptools-0.7.1-cp311-cp311-win_amd64.whl (86 kB)
#      ---------------------------------------- 86.9/86.9 kB 5.1 MB/s eta 0:00:00
# Collecting anyio>=4.0.0
#   Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
#      ---------------------------------------- 114.4/114.4 kB ? eta 0:00:00
# Collecting python-multipart>=0.0.10
#   Downloading python_multipart-0.0.28-py3-none-any.whl (29 kB)
# Collecting websockets>=12.0.0
#   Downloading websockets-16.0-cp311-cp311-win_amd64.whl (178 kB)
#      -------------------------------------- 178.7/178.7 kB 5.3 MB/s eta 0:00:00
# Collecting itsdangerous>=2.1.2
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting watchdog<7,>=2.1.5
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
#      ---------------------------------------- 79.1/79.1 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata
#   Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
#      -------------------------------------- 349.3/349.3 kB 7.4 MB/s eta 0:00:00
# Collecting narwhals>=1.15.1
#   Downloading narwhals-2.21.0-py3-none-any.whl (451 kB)
#      ------------------------------------- 451.9/451.9 kB 14.2 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ---------------------------------------- 134.9/134.9 kB ? eta 0:00:00
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.26.0-py3-none-any.whl (90 kB)
#      ---------------------------------------- 90.6/90.6 kB 5.4 MB/s eta 0:00:00
# Collecting idna>=2.8
#   Downloading idna-3.14-py3-none-any.whl (72 kB)
#      ---------------------------------------- 72.2/72.2 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python311\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.7-cp311-cp311-win_amd64.whl (159 kB)
#      -------------------------------------- 159.3/159.3 kB 9.3 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.26
#   Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
#      -------------------------------------- 131.1/131.1 kB 7.6 MB/s eta 0:00:00
# Collecting certifi>=2023.5.7
#   Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
#      -------------------------------------- 135.7/135.7 kB 7.8 MB/s eta 0:00:00
# Collecting h11>=0.8
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Collecting MarkupSafe>=2.0
#   Downloading markupsafe-3.0.3-cp311-cp311-win_amd64.whl (15 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
#      ---------------------------------------- 67.5/67.5 kB 3.6 MB/s eta 0:00:00
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.37.0-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.25.0
#   Downloading rpds_py-0.30.0-cp311-cp311-win_amd64.whl (236 kB)
#      -------------------------------------- 236.0/236.0 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: websockets, watchdog, urllib3, tzdata, toml, tenacity, smmap, rpds-py, python-multipart, pyarrow, protobuf, pillow, numpy, narwhals, MarkupSafe, itsdangerous, idna, httptools, h11, click, charset_normalizer, certifi, cachetools, blinker, attrs, uvicorn, requests, referencing, plotly, pandas, jinja2, gitdb, anyio, starlette, pydeck, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed MarkupSafe-3.0.3 altair-6.1.0 anyio-4.13.0 attrs-26.1.0 blinker-1.9.0 cachetools-7.1.1 certifi-2026.4.22 charset_normalizer-3.4.7 click-8.3.3 gitdb-4.0.12 gitpython-3.1.50 h11-0.16.0 httptools-0.7.1 idna-3.14 itsdangerous-2.2.0 jinja2-3.1.6 jsonschema-4.26.0 jsonschema-specifications-2025.9.1 narwhals-2.21.0 numpy-2.4.4 pandas-3.0.2 pillow-12.2.0 plotly-6.7.0 protobuf-7.34.1 pyarrow-24.0.0 pydeck-0.9.2 python-multipart-0.0.28 referencing-0.37.0 requests-2.33.1 rpds-py-0.30.0 smmap-5.0.3 starlette-1.0.0 streamlit-1.57.0 tenacity-9.1.4 toml-0.10.2 tzdata-2026.2 urllib3-2.7.0 uvicorn-0.46.0 watchdog-6.0.0 websockets-16.0
# [notice] A new release of pip available: 22.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd 
import plotly.express as px
# Out:
# Writing app.py

# %%
st.title("Nassau Candy Distributor Sales Analysis")
Products_data = pd.read_csv(r"C:\Users\user\Documents\GitHub\Unified-Mentor-Project-1\Groupby Product Name.csv")
# Out:
# 2026-05-11 16:24:48.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-11 16:24:48.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-11 16:24:48.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
top_products = Products_data.sort_values(by = 'Gross Profit', ascending = False)
fig = px.bar(top_products, x = 'Product Name',y = 'Gross Profit', orientation = 'h',title ='Products by Profit',text = 'Gross Profit')
st.plotly_chart(fig)
# Out:
# 2026-05-11 16:37:21.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-11 16:37:21.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-11 16:37:21.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-11 16:37:21.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-11 16:37:21.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
